# %%
u = plot(vector([2,4,2]))
v = plot(vector([0,-1,2]))
w = plot(vector([-5,2,1]))

u+v+w
# Out:
# Graphics3d Object

# %%
u = plot(arrow((0,0,0),(2,4,2)))
v = plot(arrow((0,0,0),(0,-1,2)))
w = plot(arrow((0,0,0),(-5,2,1)))

u+v+w
# Out:
# Graphics3d Object

# %%
var("y")
var("z")
t(x,y,z) = 100*(14^0.5)/((x^2+y^2+z^2)*((x^2)+(y^2)+(z^2))^0.5)
diff(t, x)
# Out:
# (x, y, z) |--> -1122.49721603218*x/(x^2 + y^2 + z^2)^2.50000000000000

# %%
var("y")
var("z")
t(x,y,z) = 100*(14^0.5)/((x^2+y^2+z^2)*((x^2)+(y^2)+(z^2))^0.5)
diff(t, y)
# Out:
# (x, y, z) |--> -1122.49721603218*y/(x^2 + y^2 + z^2)^2.50000000000000

# %%
var("y")
var("z")
t(x,y,z) = 100*(14^0.5)/((x^2+y^2+z^2)*((x^2)+(y^2)+(z^2))^0.5)
diff(t, z)
# Out:
# (x, y, z) |--> -1122.49721603218*z/(x^2 + y^2 + z^2)^2.50000000000000
